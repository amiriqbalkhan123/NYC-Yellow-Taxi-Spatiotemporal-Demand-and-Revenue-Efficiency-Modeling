# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_parquet('hourly_summary.parquet')
df.head()
# Out:
#    hour  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0     0      906085    27206378.03  30.026298      3.953933  14.814035
# 1     1      586182    15967830.54  27.240397      3.462436  13.637324
# 2     2      372693     9347621.18  25.081290      3.039199  12.410103
# 3     3      238342     6162852.87  25.857184      3.200313  12.076259
# 4     4      155964     5149171.03  33.015125      4.524116  13.667195

# %%
df.head(25)
# Out:
#     hour  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0      0      906085    27206378.03  30.026298      3.953933  14.814035
# 1      1      586182    15967830.54  27.240397      3.462436  13.637324
# 2      2      372693     9347621.18  25.081290      3.039199  12.410103
# 3      3      238342     6162852.87  25.857184      3.200313  12.076259
# 4      4      155964     5149171.03  33.015125      4.524116  13.667195
# 5      5      176703     6702692.86  37.931970      5.640430  14.511529
# 6      6      402413    12285669.47  30.530001      4.346215  14.351367
# 7      7      845335    23063529.87  27.283302      3.419053  15.010847
# 8      8     1196676    31345463.28  26.193776      2.938067  15.114823
# 9      9     1419864    37661083.60  26.524430      2.869164  15.631537
# 10    10     1587147    42899219.12  27.029140      2.895709  16.220714
# 11    11     1725125    47273318.95  27.402837      2.887626  16.888705
# ...

# %%
monthly_summary = pd.read_parquet('monthly_summary.parquet')
monthly_summary.head(25)
# Out:
#     month  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0       1     2752628    74921374.44  27.218126      3.050284  14.577738
# 1       2     2599121    69921520.90  26.901988      2.981682  14.850492
# 2       3     3015063    84478047.48  28.018667      3.185436  15.649081
# 3       4     2992143    84752728.14  28.325093      3.163116  16.174112
# 4       5     3121083    92388448.11  29.601407      3.321262  17.439091
# 5       6     2838991    83846836.23  29.534027      3.352754  16.881824
# 6       7     2594458    75527143.65  29.110953      3.344164  16.379070
# 7       8     2417131    71136705.10  29.430223      3.492977  16.310868
# 8       9     2879717    86034769.29  29.876120      3.307509  17.617658
# 9      10     3110938    92653556.54  29.783158      3.248464  17.529622
# 10     11     2888381    84060611.67  29.103021      3.150982  17.052648
# 11     12     3131289    90856380.51  29.015648      3.192433  18.348318

# %%
monthly_summary.head(25)
# Out:
#     month  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0       1     2752628    74921374.44  27.218126      3.050284  14.577738
# 1       2     2599121    69921520.90  26.901988      2.981682  14.850492
# 2       3     3015063    84478047.48  28.018667      3.185436  15.649081
# 3       4     2992143    84752728.14  28.325093      3.163116  16.174112
# 4       5     3121083    92388448.11  29.601407      3.321262  17.439091
# 5       6     2838991    83846836.23  29.534027      3.352754  16.881824
# 6       7     2594458    75527143.65  29.110953      3.344164  16.379070
# 7       8     2417131    71136705.10  29.430223      3.492977  16.310868
# 8       9     2879717    86034769.29  29.876120      3.307509  17.617658
# 9      10     3110938    92653556.54  29.783158      3.248464  17.529622
# 10     11     2888381    84060611.67  29.103021      3.150982  17.052648
# 11     12     3131289    90856380.51  29.015648      3.192433  18.348318

# %%
monthly_summary.to_parquet('monthly_summary.parquet', index=False)

# %%
monthly_summary.head(25)
# Out:
#     month  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0       1     2752628    74921374.44  27.218126      3.050284  14.577738
# 1       2     2599121    69921520.90  26.901988      2.981682  14.850492
# 2       3     3015063    84478047.48  28.018667      3.185436  15.649081
# 3       4     2992143    84752728.14  28.325093      3.163116  16.174112
# 4       5     3121083    92388448.11  29.601407      3.321262  17.439091
# 5       6     2838991    83846836.23  29.534027      3.352754  16.881824
# 6       7     2594458    75527143.65  29.110953      3.344164  16.379070
# 7       8     2417131    71136705.10  29.430223      3.492977  16.310868
# 8       9     2879717    86034769.29  29.876120      3.307509  17.617658
# 9      10     3110938    92653556.54  29.783158      3.248464  17.529622
# 10     11     2888381    84060611.67  29.103021      3.150982  17.052648
# 11     12     3131289    90856380.51  29.015648      3.192433  18.348318

# %%
daily_summary = pd.read_parquet('daily_summary.parquet')

# %%
daily_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           367 non-null    object
#  1   trip_count     367 non-null    int64
#  2   total_revenue  367 non-null    float64
#  3   avg_fare       367 non-null    float64
#  4   avg_distance   367 non-null    float64
#  5   avg_trip       367 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
daily_summary.duplicated().sum()
# Out:
# 0

# %%
daily_summary.isna().sum()
# Out:
# date             0
# trip_count       0
# total_revenue    0
# avg_fare         0
# avg_distance     0
# avg_trip         0
# dtype: int64

# %%
daily_summary.shape
# Out:
# (367, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hour           24 non-null     int32
#  1   trip_count     24 non-null     int64
#  2   total_revenue  24 non-null     float64
#  3   avg_fare       24 non-null     float64
#  4   avg_distance   24 non-null     float64
#  5   avg_trip       24 non-null     float64
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 1.2 KB

# %%
daily_summary['date'] = pd.to_datetime(daily_summary['date'])

# %%
daily_summary = daily_summary[daily_summary['date'] >=  '2025-01-01']

# %%
daily_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 33 to 366
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           334 non-null    datetime64[ns]
#  1   trip_count     334 non-null    int64
#  2   total_revenue  334 non-null    float64
#  3   avg_fare       334 non-null    float64
#  4   avg_distance   334 non-null    float64
#  5   avg_trip       334 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 18.3 KB

# %%
daily_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 33 to 366
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           334 non-null    datetime64[ns]
#  1   trip_count     334 non-null    int64
#  2   total_revenue  334 non-null    float64
#  3   avg_fare       334 non-null    float64
#  4   avg_distance   334 non-null    float64
#  5   avg_trip       334 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 18.3 KB

# %%
daily_summary['date'].describe()
# Out:
# count                    334
# mean     2025-06-16 12:00:00
# min      2025-01-01 00:00:00
# 25%      2025-03-25 06:00:00
# 50%      2025-06-16 12:00:00
# 75%      2025-09-07 18:00:00
# max      2025-11-30 00:00:00
# Name: date, dtype: object

# %%
daily_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 33 to 366
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           334 non-null    datetime64[ns]
#  1   trip_count     334 non-null    int64
#  2   total_revenue  334 non-null    float64
#  3   avg_fare       334 non-null    float64
#  4   avg_distance   334 non-null    float64
#  5   avg_trip       334 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 18.3 KB

# %%
daily_summary.head(40)
# Out:
#          date  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 33 2025-01-01       69295     2001591.19  28.885074      3.817844  15.248185
# 34 2025-01-02       75365     2191721.02  29.081417      3.572969  16.274988
# 35 2025-01-03       81480     2249560.59  27.608746      3.267998  15.486901
# 36 2025-01-04       87695     2311377.80  26.357008      3.174483  14.809661
# 37 2025-01-05       70645     2045995.52  28.961647      3.765098  14.503074
# 38 2025-01-06       70953     2014714.71  28.395060      3.408958  14.489191
# 39 2025-01-07       86563     2310716.56  26.694044      2.973956  14.368352
# 40 2025-01-08       93708     2456516.59  26.214588      2.813743  14.200388
# 41 2025-01-09       97745     2623546.36  26.840722      2.912170  14.946523
# 42 2025-01-10       92002     2500120.23  27.174629      3.043261  14.590067
# 43 2025-01-11       97876     2466903.52  25.204376      2.884231  13.437799
# ...

# %%
daily_summary.shape
# Out:
# (334, 6)

# %%
df.head(40)
# Out:
#     hour  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0      0      906085    27206378.03  30.026298      3.953933  14.814035
# 1      1      586182    15967830.54  27.240397      3.462436  13.637324
# 2      2      372693     9347621.18  25.081290      3.039199  12.410103
# 3      3      238342     6162852.87  25.857184      3.200313  12.076259
# 4      4      155964     5149171.03  33.015125      4.524116  13.667195
# 5      5      176703     6702692.86  37.931970      5.640430  14.511529
# 6      6      402413    12285669.47  30.530001      4.346215  14.351367
# 7      7      845335    23063529.87  27.283302      3.419053  15.010847
# 8      8     1196676    31345463.28  26.193776      2.938067  15.114823
# 9      9     1419864    37661083.60  26.524430      2.869164  15.631537
# 10    10     1587147    42899219.12  27.029140      2.895709  16.220714
# 11    11     1725125    47273318.95  27.402837      2.887626  16.888705
# ...

# %%
borough_summary = pd.read_parquet('borough_summary.parquet')
# Out:
#     borough_id  total_trips  total_revenue   avg_fare  avg_distance
# 0            1         1022      101438.20  99.254599      3.504452
# 1            2           47        3283.39  69.859362     14.900426
# 2            3           79        2472.47  31.297089      4.970506
# 3            4        38382      938360.00  24.447918      2.570895
# 4            5            3         180.68  60.226667      4.563333
# 5            6          473       10185.01  21.532791      6.075899
# 6            7        11815      315469.52  26.700763      3.148212
# 7            8          165       11830.31  71.698848      5.095818
# 8            9          126        4162.98  33.039524      4.880556
# 9           10         7876      695565.80  88.314601     12.603191
# 10          11           92        6235.62  67.778478      5.120870
# 11          12        11432      384679.35  33.649348      4.281132
# 12          13       187456     6264478.51  33.418394      4.338332
# ...

# %%
borough_summary.shape
# Out:
# (260, 5)

# %%
daily_summary.to_parquet('daily_summary_updated.parquet', index=False)

# %%
hourly_summary.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 hourly_summary.head()
#
# NameError: name 'hourly_summary' is not defined

# %%
hourly_summary = pd.read_parquet('hourly_summary.parquet')

# %%
hourly_summary.head(30)
# Out:
#     hour  trip_count  total_revenue   avg_fare  avg_distance   avg_trip
# 0      0      906085    27206378.03  30.026298      3.953933  14.814035
# 1      1      586182    15967830.54  27.240397      3.462436  13.637324
# 2      2      372693     9347621.18  25.081290      3.039199  12.410103
# 3      3      238342     6162852.87  25.857184      3.200313  12.076259
# 4      4      155964     5149171.03  33.015125      4.524116  13.667195
# 5      5      176703     6702692.86  37.931970      5.640430  14.511529
# 6      6      402413    12285669.47  30.530001      4.346215  14.351367
# 7      7      845335    23063529.87  27.283302      3.419053  15.010847
# 8      8     1196676    31345463.28  26.193776      2.938067  15.114823
# 9      9     1419864    37661083.60  26.524430      2.869164  15.631537
# 10    10     1587147    42899219.12  27.029140      2.895709  16.220714
# 11    11     1725125    47273318.95  27.402837      2.887626  16.888705
# ...
